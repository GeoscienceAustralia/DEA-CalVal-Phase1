# %%
import pandas as pd
from datetime import date
krain = pd.read_csv('IDCJAC0009_024564_1800_Data.csv')

# %%
for i in range(len(krain.Year)):
    (date(krain.Year[i], krain.Month[i], krain.Day[i])-date(2017,12,31)).days

# %%
krain.rename({'Rainfall amount (millimetres)': 'rain'}, axis=1, inplace=True)

# %%
rainday = [(date(krain.Year[i], krain.Month[i], krain.Day[i])-date(2017,12,31)).days for i in range(len(krain.Year))]

# %%
rainday
# Out:
# [-18262,
#  -18261,
#  -18260,
#  -18259,
#  -18258,
#  -18257,
#  -18256,
#  -18255,
#  -18254,
#  -18253,
#  -18252,
#  -18251,
#  -18250,
#  -18249,
#  -18248,
#  -18247,
#  -18246,
#  -18245,
#  -18244,
#  -18243,
#  -18242,
#  -18241,
#  -18240,
#  -18239,
#  -18238,
#  -18237,
#  -18236,
#  -18235,
#  -18234,
#  -18233,
#  -18232,
#  -18231,
#  -18230,
#  -18229,
#  -18228,
#  -18227,
#  -18226,
#  -18225,
#  -18224,
#  -18223,
#  -18222,
#  -18221,
#  -18220,
#  -18219,
#  -18218,
#  -18217,
#  -18216,
#  -18215,
#  -18214,
#  -18213,
#  -18212,
#  -18211,
#  -18210,
#  -18209,
#  -18208,
#  -18207,
#  -18206,
#  -18205,
#  -18204,
#  -18203,
#  -18202,
#  -18201,
#  -18200,
#  -18199,
#  -18198,
#  -18197,
#  -18196,
#  -18195,
#  -18194,
#  -18193,
#  -18192,
#  -18191,
#  -18190,
#  -18189,
#  -18188,
#  -18187,
#  -18186,
#  -18185,
#  -18184,
#  -18183,
#  -18182,
#  -18181,
#  -18180,
#  -18179,
#  -18178,
#  -18177,
#  -18176,
#  -18175,
#  -18174,
#  -18173,
# ...

# %%
len(rainday)
# Out:
# 18552

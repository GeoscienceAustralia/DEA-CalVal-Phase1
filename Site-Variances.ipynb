# %%
import pandas as pd
import numpy as np

data = np.array([['','site','date','sensor','maxv','minv','meanv'],
                 [1,'PIN','28MAR18','S2b',5.4,2.8,3.4],
                 [2,'PIN','02APR18','L8',5.0,2.2,3.6],
                 [3,'PIN','02APR18','S2a',4.0,2.4,3.2],
                 [4,'PIN','12APR18','S2a',5.2,3.0,3.5],
                 [5,'PIN','12MAY18','S2a',5.8,4.2,4.6],
                 [6,'PIN','20MAY18','L8',6.1,4.5,5.2],
                 [7,'PIN','22MAY18','S2a',5.1,3.8,4.8],
                 [8,'LKG2','12FEB18','L8',7.0,5.6,6.5],
                 [9,'LKG','12FEB18','L8',2.2,0.9,1.7],
                 [10,'LKG','26MAR18','S2b',6.9,4.0,5.8],
                 [11,'LKG','05APR18','S2b',4.9,2.9,4.0],
                 [12,'LKG','03MAY18','L8',5.5,3.6,4.5],
                 [13,'LKG','04JUL18','S2b',8.8,6.4,7.5],
                 [14,'NRB','06MAR18','S2b',6.5,1.4,3.1],
                 [15,'NRB','11MAR18','S2a',5.2,1.5,2.8],
                 [16,'NRB','17APR18','L8',19.7,2.8,11.5],
                 [17,'NRB','09JUL18','S2a',12.1,4.8,7.7],
                 [18,'DOO','14MAR18','L8',1.1,0.3,0.9],
                 [19,'DOO','14MAR18','S2a',2.1,0.9,1.3],
                 [20,'WIN','07MAY18','S2b',10.5,4.3,6.8],
                 [21,'BLA','22APR18','S2a',3.8,0.9,2.4],
                 [22,'LIT','29JUN18','S2a',6.5,1.6,5.0]])

df = pd.DataFrame(data=data[1:,1:],
                  index=data[1:,0],
                  columns=data[0,1:])

# %%
df
# Out:
#     site     date sensor  maxv minv meanv
# 1    PIN  28MAR18    S2b   5.4  2.8   3.4
# 2    PIN  02APR18     L8   5.0  2.2   3.6
# 3    PIN  02APR18    S2a   4.0  2.4   3.2
# 4    PIN  12APR18    S2a   5.2  3.0   3.5
# 5    PIN  12MAY18    S2a   5.8  4.2   4.6
# 6    PIN  20MAY18     L8   6.1  4.5   5.2
# 7    PIN  22MAY18    S2a   5.1  3.8   4.8
# 8   LKG2  12FEB18     L8   7.0  5.6   6.5
# 9    LKG  12FEB18     L8   2.2  0.9   1.7
# 10   LKG  26MAR18    S2b   6.9  4.0   5.8
# 11   LKG  05APR18    S2b   4.9  2.9   4.0
# 12   LKG  03MAY18     L8   5.5  3.6   4.5
# 13   LKG  04JUL18    S2b   8.8  6.4   7.5
# 14   NRB  06MAR18    S2b   6.5  1.4   3.1
# 15   NRB  11MAR18    S2a   5.2  1.5   2.8
# 16   NRB  17APR18     L8  19.7  2.8  11.5
# 17   NRB  09JUL18    S2a  12.1  4.8   7.7
# 18   DOO  14MAR18     L8   1.1  0.3   0.9
# 19   DOO  14MAR18    S2a   2.1  0.9   1.3
# 20   WIN  07MAY18    S2b  10.5  4.3   6.8
# 21   BLA  22APR18    S2a   3.8  0.9   2.4
# ...
